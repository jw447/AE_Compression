# %%
import numpy as np
import matplotlib.pyplot as plt

f = open('data/md_0_seg.txt','r')
input_data = f.readlines()

for i in range(1,100):
    f = open('data/md_'+str(i)+'_seg.txt','r')
    input_data = np.concatenate([input_data,f.readlines()],0)

# input_data = np.concatenate([input_data0,input_data1,input_data2],0)
print(np.shape(input_data))
# print(input_data[1000])
input_data = [[float(line.split(' ')[1]),float(line.split(' ')[2]),float(line.split(' ')[3])] for line in input_data]
print(np.shape(input_data))
# Out:
# (10000000,)
# (10000000, 3)

# %%
input_data = np.reshape(input_data,[10000,1000,3])

# %%
fig = plt.figure(figsize=[20,4])
ax = plt.subplot(111)
ax.plot(np.arange(0,10000),input_data[0:10000,0,0],'r-',label='x')
ax.plot(np.arange(0,10000),input_data[0:10000,0,1],'g-',label='y')
ax.plot(np.arange(0,10000),input_data[0:10000,0,2],'b-',label='z')

ax.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(input_data[0,0:50,0], input_data[0,0:50,1], input_data[0,0:50,2], c='r', marker='o',s=50)
ax.scatter(input_data[50,0:50,0], input_data[50,0:50,1], input_data[50,0:50,2], c='g', marker='o',s = 50)
ax.scatter(input_data[100,0:50,0], input_data[100,0:50,1], input_data[100,0:50,2], c='b', marker='o',s = 50)

for i in range(50):
    ax.plot(input_data[[0,50,100],i,0],input_data[[0,50,100],i,1],input_data[[0,50,100],i,2],'c-',linewidth=1)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
input_data[0,0:50,0]
# Out:
# array([4.21778, 4.27991, 4.18365, 4.14036, 4.27443, 4.31967, 4.38936,
#        4.48185, 4.36099, 4.43775, 4.35904, 4.45057, 4.56954, 4.65874,
#        4.54609, 4.59956, 4.51603, 4.61709, 4.72067, 4.7334 , 4.80534,
#        4.72074, 4.15726, 4.08657, 4.15151, 4.21068, 4.06847, 3.98806,
#        4.01438, 4.09308, 3.96496, 4.04529, 3.88621, 3.92219, 3.89502,
#        3.80807, 3.92316, 3.85738, 4.15849, 4.26498, 4.13073, 4.04397,
#        4.21068, 4.31583, 4.1838 , 4.07884, 4.18351, 4.28237, 4.26946,
#        4.18661])

# %%
input_data[0,0:50,1]
# Out:
# array([3.24237, 3.32111, 3.22887, 3.27393, 3.11525, 3.07968, 3.13503,
#        3.17738, 3.20757, 3.0103 , 2.98162, 2.92642, 3.03873, 3.06258,
#        3.12452, 2.91943, 2.89576, 2.83476, 2.93429, 2.84618, 2.94295,
#        3.01028, 3.03636, 3.08959, 2.90556, 2.86758, 2.81243, 2.86058,
#        2.70623, 2.68252, 2.57432, 2.51857, 2.59345, 2.51271, 2.76341,
#        2.78644, 2.85972, 2.70457, 2.74295, 2.69135, 2.7517 , 2.79841,
#        2.68914, 2.69727, 2.75602, 2.78542, 2.68154, 2.86482, 2.9936 ,
#        3.02267])

# %%
[input_data[0,0,0],input_data[0,0,1],input_data[0,0,2]]
# Out:
# [4.21778, 3.24237, 2.26233]

# %%
input_data[0,0]
# Out:
# array([4.21778, 3.24237, 2.26233])

# %%
input_data[0,0:50,0]
# Out:
# array([4.21778, 4.27991, 4.18365, 4.14036, 4.27443, 4.31967, 4.38936,
#        4.48185, 4.36099, 4.43775, 4.35904, 4.45057, 4.56954, 4.65874,
#        4.54609, 4.59956, 4.51603, 4.61709, 4.72067, 4.7334 , 4.80534,
#        4.72074, 4.15726, 4.08657, 4.15151, 4.21068, 4.06847, 3.98806,
#        4.01438, 4.09308, 3.96496, 4.04529, 3.88621, 3.92219, 3.89502,
#        3.80807, 3.92316, 3.85738, 4.15849, 4.26498, 4.13073, 4.04397,
#        4.21068, 4.31583, 4.1838 , 4.07884, 4.18351, 4.28237, 4.26946,
#        4.18661])

# %%
input_data[0,0:50,1]
# Out:
# array([3.24237, 3.32111, 3.22887, 3.27393, 3.11525, 3.07968, 3.13503,
#        3.17738, 3.20757, 3.0103 , 2.98162, 2.92642, 3.03873, 3.06258,
#        3.12452, 2.91943, 2.89576, 2.83476, 2.93429, 2.84618, 2.94295,
#        3.01028, 3.03636, 3.08959, 2.90556, 2.86758, 2.81243, 2.86058,
#        2.70623, 2.68252, 2.57432, 2.51857, 2.59345, 2.51271, 2.76341,
#        2.78644, 2.85972, 2.70457, 2.74295, 2.69135, 2.7517 , 2.79841,
#        2.68914, 2.69727, 2.75602, 2.78542, 2.68154, 2.86482, 2.9936 ,
#        3.02267])

# %%
input_data[0,0:50,2]
# Out:
# array([2.26233, 2.25046, 2.16824, 2.319  , 2.31   , 2.21743, 2.40888,
#        2.36972, 2.48513, 2.48291, 2.55264, 2.4145 , 2.55503, 2.4971 ,
#        2.61805, 2.64582, 2.71172, 2.57945, 2.72799, 2.77569, 2.67361,
#        2.79453, 2.36667, 2.45196, 2.34057, 2.26805, 2.41426, 2.46991,
#        2.31848, 2.24688, 2.37795, 2.4261 , 2.45085, 2.29886, 2.24193,
#        2.30349, 2.19934, 2.15824, 2.51542, 2.48219, 2.64571, 2.66792,
#        2.74911, 2.72156, 2.88396, 2.88371, 2.96355, 2.91929, 2.8659 ,
#        2.80301])

# %%
input_data[[0,100,200],0,0]
# Out:
# array([4.21778, 4.25519, 4.25227])
